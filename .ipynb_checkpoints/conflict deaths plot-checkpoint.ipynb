# %%
# %config Completer.use_jedi = False

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from math import floor, log10


plt.style.use('../Nilerat_matplotlib_stylesheet.mplstyle')

# %%
data = pd.read_csv('List_of_wars_and_anthropogenic_disasters_by_death_toll_1.csv', thousands=',', nrows=75)
data['geomean'] = data['Geometric mean estimate']
data['log'] = data['geomean'].apply(np.log10)

# %%
data['Geometric mean estimate']
# Out:
# 0     91021920
# 1     41352146
# 2     28284271
# 3     25922963
# 4     25000000
#         ...
# 70      234521
# 71      234000
# 72      233000
# 73      228000
# 74      223607
# Name: Geometric mean estimate, Length: 75, dtype: int64

# %%
def annotate_point(xy,  
                   text, 
                   xytext, 
                   ax,
                   relpos=(0.5, 0.5),
                   lw=0.5,
                   color='0.15',
                   fontsize=6,
                   fontweight='regular',
                   fontcolor='0.1',
                   ha='center',
                   zorder=6,
                   circle_size=20, 
                   bbox_pad=0,
                   bbox_facecolor='white',
                   highlight=False,
                   **kwargs
                  ):
    """
    Convenience function for streamlining annotation 
    on slope vs. slope and volcano plots. 
    
    Position of text is given in the difference in 'axes fraction' 
    away from the point for easier eyeballing. 
    
    xytext values should be a percentage (e.g. 8) rather than a decimal (0.08) 
    
    """
    frac_to_data = ax.transLimits.inverted().transform  # converts axes fraction to data coords
    # To calculate the xytext as a delta, find the difference in data coords from (0, 0)
    xtextdelta, ytextdelta = (frac_to_data(xytext) - frac_to_data([0, 0])) / 100
    xytext = (xy[0] + xtextdelta, xy[1] + ytextdelta)
    if highlight:
        bbox_pad = HIGHLIGHT_BBOX_PAD
        fontsize = HIGHLIGHT_FONTSIZE
        fontweight = HIGHLIGHT_FONTWEIGHT
        bbox_facecolor = HIGHLIGHT_FACECOLOR
        lw = HIGHLIGHT_ANNOT_LW
        zorder = zorder + 1
    ax.annotate(
        text=text, 
        xy=xy, 
        xytext=xytext, #(counter+5, row['coef']+0.05),
        textcoords='data',
        arrowprops=dict(arrowstyle='-', 
                        relpos=relpos, 
                        lw=lw, 
                        color=color),
        bbox=dict(pad=bbox_pad, 
                  facecolor=bbox_facecolor, 
                  edgecolor='none'),
        fontsize=fontsize, 
        fontweight=fontweight,
        color=fontcolor,
        annotation_clip=True, 
        ha=ha, va='center',
        zorder=zorder,
        **kwargs
    )
    # Draw circle around point
    alpha_corrected_color = (str(float(color) - 0.15))
    ax.scatter(xy[0], xy[1], 
               edgecolor=alpha_corrected_color, facecolor='white', linewidth=lw, alpha=0.7,
               s=circle_size, zorder=zorder)

    
round_to_n = lambda x, n: round(x, -int(floor(log10(x))) + (n - 1))


def find_nth(haystack, needle, n):
    start = haystack.find(needle)
    while start >= 0 and n > 1:
        start = haystack.find(needle, start+len(needle))
        n -= 1
    return start

# %%
find_nth('asdf asdf asdf asdf', ' ', 5)
# Out:
# -1

# %%
def year_mapper(x):
    if x >= 1500:
        return 1500 + (x-1500) * 6.5
    else:
        return x
    
def human_format(num):
    num = float('{:.2g}'.format(num))
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    return '{}{}'.format('{:f}'.format(num).rstrip('0').rstrip('.'), ['', 'K', 'M', 'B', 'T'][magnitude])

# %%
df
# Out:
#                                     Event                    Altname  \
# 0                            World War II               World War II
# 1                        Mongol conquests           Mongol conquests
# 2                       Taiping Rebellion          Taiping Rebellion
# 3   European colonization of the Americas      Euro. col of Americas
# 4            Transition from Ming to Qing    Ming to Qing transition
# 5                Second Sino-Japanese War      2nd Sino-Japanese War
# 8          Civil war in China. See also: Qing dynasty  10000000  7.000000
# 9   Major civil war in China that led to the found...   9671401  6.985489
# 10   See also: Russian Revolution, List of civil wars   6708204  6.826606
# 11  Initially a religious war between Catholics an...   6000000  6.778151
# 12                                                NaN   5600000  6.748188
# 13               See also: Napoleonic Wars casualties   4949747  6.694583
# 14                     Part of the Three Kingdoms War   4582576  6.661110
# 15                                                NaN   3674235  6.565167
# 16  Largely a religious war between Catholics and ...   2828427  6.451545
# 17  Edwardian War (1337–1360), Caroline War (1369–...   2754995  6.440121
# 18                              Part of the Cold War.   2598076  6.414652
# 19                         See also: History of China   2000000  6.301030
#
#     yearmap
# 0    4392.5
# 1    1405.0
# 2    3866.0
# 3    2741.5
# 4    2689.5
# 5    4392.5
# 6    4217.0
# 7     763.0
# 8    3950.5
# 9    4418.5
# 10   4236.5
# 11   2462.0
# 12   2845.5
# 13   3547.5
# 14    205.0
# 15   4769.5
# 16   2137.0
# 17   1453.0
# 18   4444.5
# 19   -221.0

# %%
fig, ax = plt.subplots(dpi=250, figsize=(3, 2))
df = data.iloc[:20].copy()
df['yearmap'] = df['End'].apply(year_mapper)

xcol = 'yearmap'
ycol = 'log'

sns.scatterplot(
    data=df, x=xcol, y=ycol, 
#     size='geomean', sizes=(10, 100),
    linewidth=0,
    zorder=10,
)
ax.set_xlabel('Conflict end year')
ax.set_ylabel('Conflict death toll')
xs = [-250, 0, 500, 1000, 1500, 1600, 1700, 1800, 1900, 2000]
xticklabels = [str(x) for x in xs]
xticklabels[0] = '250 BCE'
ax.set_xticks([year_mapper(x) for x in xs], xticklabels, fontsize=5, rotation=90)

yticks = np.log10([2e6, 3e6, 5e6, 1e7, 2e7, 3e7, 5e7, 1e8])
ax.set_yticks(yticks, ['2M', '3M', '5M', '10M', '20M', '30M', '50M', '100M'])

ax.set_ylim(bottom=df[ycol].min() - 0.2, top=8.2)

ax.set_axisbelow(True)
ax.grid(axis='y', lw=0.5, color='0.8')
ax.tick_params(length=0, pad=1)
sns.despine(left=True)

offsets = {
    0: (-15, 0),  # ww2
    1: (-10, 5, 'Mongol\nconquests'),  # mongol
    2: (10, 10, 'Taiping\nrebellion'),   # taiping
    3: (0, 15),  # euro col
    4: (-15, 10), # ming to qing
    5: (15, 15, '2nd Sino-\nJapanese war'),  # 2nd sino-japanese
    6: (15, 0),   # ww1
    7: (-11, 11, 'An Lushan\nrebellion'),  # an-lushan
    8: (-11, 8, 'Dungan\nrebellion'),
    9: (12, 0, 'Chinese\ncivil war'),
    10: (12, 0, 'Russian\ncivil war')
    
}
for i, row in df.iterrows():
    x = row[xcol]
    y = row[ycol]
    name = row['Altname']
    if len(name) > 10:
        pos = find_nth(name, ' ', 3)
#         if pos == -1:
#             pos = find_nth(name, ' ', 2)
        if pos != -1:
            name = list(name)
            name[pos] = '\n'
            name = ''.join(name)
    if offsets.get(i) and len(offsets[i]) > 2:
        name = offsets[i][2]
    text = name + f'\n{human_format(10**y)}'
    if i in offsets:
        xytext = (offsets[i][0], offsets[i][1])
    else:
        xytext = (4, 4)
    annotate_point(xy=(x, y), text=text, xytext=xytext, ax=ax,
        circle_size=2, fontsize=4.5,
        bbox_facecolor='none', bbox_pad=-2,
                  )

# %%
int(round_to_n(10**6.5, 3))
# Out:
# 3160000

# %%
y
# Out:
# 6.301029995663981
